# %%
import os, sys
import requests
from urllib.parse import urljoin, urlparse
from bs4 import BeautifulSoup as bs
import re
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
# %config InlineBackend.figure_format = 'retina'
from pandas.plotting import lag_plot

# %%
from sklearn.metrics import r2_score
from math import sqrt

# %%
import warnings
warnings.filterwarnings('ignore')
warnings.simplefilter(action='ignore', category=FutureWarning)

# %%
from sklearn.preprocessing import MinMaxScaler
from keras.models import Sequential
from keras.layers import Dense, LSTM, Dropout, GRU, Bidirectional
# from keras.optimizers import SGD
from tensorflow.keras.optimizers import SGD

import math
from sklearn.metrics import mean_squared_error

# %%
from sklearn.linear_model import LinearRegression
from sklearn.preprocessing import StandardScaler, PolynomialFeatures

# %%
# !pip install gif

# %%
from pandas.plotting import autocorrelation_plot
# import gif
import json

# %%
from statsmodels.tsa.ar_model import AutoReg
from sklearn.metrics import mean_squared_error

# %%
import tensorflow as tf
tf.__version__

import tensorflow as tf
from tensorflow import keras

from tqdm import tqdm

# %%
from sklearn import metrics
import statsmodels.api as sm

# %%
import sys
import os
from os.path import dirname

# %%
os.path.abspath('')
# Out:
# '/home/ec2-user/SageMaker/Codes'

# %%
parent = (dirname(os.path.abspath('')))
sys.path.insert(0, parent)

# %%
parent
# Out:
# '/home/ec2-user/SageMaker'

# %%
from utils import TimeSeries

# %% [markdown]
# # Read Datam

# %%
class LSTM_3(TimeSeries):
    # override
    def _setup_lstm_model(self, 
                   optimizer:str='rmsprop', 
                   loss:str='mean_squared_error',
                   print_summary:bool = False):
        

        self.regressor = Sequential()
        self.regressor.add(LSTM(50, activation='relu', return_sequences=True, 
                                input_shape=(self.X_train.shape[1],1)))
        self.regressor.add(LSTM(50, activation='relu'))
        #model.add(Dense(32))
        self.regressor.add(Dense(1))
        self.regressor.compile(optimizer='adam', loss='mean_squared_error')


        if print_summary:
            self.regressor.summary()

# %%
obj = LSTM_3(address=parent+"/Data/Data_ICME_speed_transformed_18D_P03_01")

# %% [markdown]
# # split_fraction = 0.69, lags = 60

# %%
obj.plot()
obj.fit_lstm(epochs=100)
obj.model_predict()
obj.compare_test_result()
# Out:
# Epoch 1/100
# 8/8 [==============================] - 1s 97ms/step - loss: 0.0986 - val_loss: 0.0533
# Epoch 2/100
# 8/8 [==============================] - 0s 56ms/step - loss: 0.0642 - val_loss: 0.0266
# Epoch 3/100
# 8/8 [==============================] - 0s 55ms/step - loss: 0.0328 - val_loss: 0.0267
# Epoch 4/100
# 8/8 [==============================] - 0s 57ms/step - loss: 0.0289 - val_loss: 0.0218
# Epoch 5/100
# 8/8 [==============================] - 0s 59ms/step - loss: 0.0293 - val_loss: 0.0217
# Epoch 6/100
# 8/8 [==============================] - 0s 55ms/step - loss: 0.0276 - val_loss: 0.0237
# Epoch 7/100
# 8/8 [==============================] - 0s 52ms/step - loss: 0.0289 - val_loss: 0.0231
# Epoch 8/100
# 8/8 [==============================] - 0s 52ms/step - loss: 0.0277 - val_loss: 0.0218
# Epoch 9/100
# 8/8 [==============================] - 0s 53ms/step - loss: 0.0281 - val_loss: 0.0219
# Epoch 10/100
# ...

# %% [markdown]
# # split_fraction = 0.8, lags = 20

# %%
obj = TimeSeries(address=parent+"/Data/Data_ICME_speed_transformed_18D_P03_01", split_fraction = 0.8, lags = 20)

# %%
obj.plot()
obj.fit_lstm(epochs=99)
obj.model_predict()
obj.compare_test_result()
# Out:
# Epoch 1/99
# 10/10 [==============================] - 2s 178ms/step - loss: 0.0732 - val_loss: 0.0242
# Epoch 2/99
# 10/10 [==============================] - 0s 35ms/step - loss: 0.0401 - val_loss: 0.0159
# Epoch 3/99
# 10/10 [==============================] - 0s 34ms/step - loss: 0.0333 - val_loss: 0.0159
# Epoch 4/99
# 10/10 [==============================] - 0s 34ms/step - loss: 0.0332 - val_loss: 0.0167
# Epoch 5/99
# 10/10 [==============================] - 0s 33ms/step - loss: 0.0338 - val_loss: 0.0166
# Epoch 6/99
# 10/10 [==============================] - 0s 33ms/step - loss: 0.0322 - val_loss: 0.0171
# Epoch 7/99
# 10/10 [==============================] - 0s 33ms/step - loss: 0.0340 - val_loss: 0.0159
# Epoch 8/99
# 10/10 [==============================] - 0s 33ms/step - loss: 0.0315 - val_loss: 0.0164
# Epoch 9/99
# 10/10 [==============================] - 0s 33ms/step - loss: 0.0330 - val_loss: 0.0167
# Epoch 10/99
# ...

# %% [markdown]
# # split_fraction = 0.8, lags = 10

# %%
obj = TimeSeries(address=parent+"/Data/Data_ICME_speed_transformed_18D_P03_01", split_fraction = 0.8, lags = 10)

# %%
obj.plot()

# %%
obj.fit_lstm(epochs=20)
obj.model_predict()
obj.compare_test_result()
# Out:
# Epoch 1/20
# 10/10 [==============================] - 2s 163ms/step - loss: 0.0800 - val_loss: 0.0356
# Epoch 2/20
# 10/10 [==============================] - 0s 21ms/step - loss: 0.0526 - val_loss: 0.0204
# Epoch 3/20
# 10/10 [==============================] - 0s 21ms/step - loss: 0.0364 - val_loss: 0.0155
# Epoch 4/20
# 10/10 [==============================] - 0s 21ms/step - loss: 0.0305 - val_loss: 0.0178
# Epoch 5/20
# 10/10 [==============================] - 0s 21ms/step - loss: 0.0320 - val_loss: 0.0160
# Epoch 6/20
# 10/10 [==============================] - 0s 21ms/step - loss: 0.0323 - val_loss: 0.0164
# Epoch 7/20
# 10/10 [==============================] - 0s 21ms/step - loss: 0.0329 - val_loss: 0.0162
# Epoch 8/20
# 10/10 [==============================] - 0s 20ms/step - loss: 0.0305 - val_loss: 0.0171
# Epoch 9/20
# 10/10 [==============================] - 0s 20ms/step - loss: 0.0339 - val_loss: 0.0160
# Epoch 10/20
# ...

# %% [markdown]
# # split_fraction = 0.5, lags = 5

# %%
obj = TimeSeries(address=parent+"/Data/Data_ICME_speed_transformed_18D_P03_01", split_fraction = 0.5, lags = 5)

# %%
obj.plot()

# %%
obj.fit_lstm(epochs=100)
obj.model_predict()
obj.compare_test_result()
# Out:
# Epoch 1/100
# 7/7 [==============================] - 2s 225ms/step - loss: 0.0960 - val_loss: 0.0198
# Epoch 2/100
# 7/7 [==============================] - 0s 17ms/step - loss: 0.0700 - val_loss: 0.0112
# Epoch 3/100
# 7/7 [==============================] - 0s 16ms/step - loss: 0.0547 - val_loss: 0.0092
# Epoch 4/100
# 7/7 [==============================] - 0s 17ms/step - loss: 0.0473 - val_loss: 0.0096
# Epoch 5/100
# 7/7 [==============================] - 0s 17ms/step - loss: 0.0408 - val_loss: 0.0141
# Epoch 6/100
# 7/7 [==============================] - 0s 17ms/step - loss: 0.0445 - val_loss: 0.0134
# Epoch 7/100
# 7/7 [==============================] - 0s 17ms/step - loss: 0.0407 - val_loss: 0.0151
# Epoch 8/100
# 7/7 [==============================] - 0s 16ms/step - loss: 0.0387 - val_loss: 0.0130
# Epoch 9/100
# 7/7 [==============================] - 0s 16ms/step - loss: 0.0441 - val_loss: 0.0140
# Epoch 10/100
# ...
