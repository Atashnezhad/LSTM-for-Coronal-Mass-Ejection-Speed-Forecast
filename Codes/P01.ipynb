# %%
import os, sys
import requests
from urllib.parse import urljoin, urlparse
from bs4 import BeautifulSoup as bs
import re
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
# %config InlineBackend.figure_format = 'retina'
from pandas.plotting import lag_plot

# %%
from sklearn.metrics import r2_score
from math import sqrt

# %%
import warnings
warnings.filterwarnings('ignore')
warnings.simplefilter(action='ignore', category=FutureWarning)

# %%
from sklearn.preprocessing import MinMaxScaler
from keras.models import Sequential
from keras.layers import Dense, LSTM, Dropout, GRU, Bidirectional
# from keras.optimizers import SGD
from tensorflow.keras.optimizers import SGD

import math
from sklearn.metrics import mean_squared_error

# %%
from sklearn.linear_model import LinearRegression
from sklearn.preprocessing import StandardScaler, PolynomialFeatures

# %%
# !pip install gif

# %%
from pandas.plotting import autocorrelation_plot
import gif
import json

# %%
from statsmodels.tsa.ar_model import AutoReg
from sklearn.metrics import mean_squared_error

# %%
import tensorflow as tf
tf.__version__

import tensorflow as tf
from tensorflow import keras

import gif
from tqdm import tqdm

# %%
from sklearn import metrics
import statsmodels.api as sm

# %%
from utils import TimeSeries

# %% [markdown]
# # Read Datam

# %%
obj = TimeSeries(address="Data/Data_ICME_speed_transformed_18D_P03_01")

# %% [markdown]
# # split_fraction = 0.69, lags = 60

# %%
obj.plot()
obj.fit_lstm(epochs=20)
obj.model_predict()
obj.compare_test_result()
# Out:
# Epoch 1/20
# 8/8 [==============================] - 2s 225ms/step - loss: 0.0794 - val_loss: 0.0265
# Epoch 2/20
# 8/8 [==============================] - 0s 49ms/step - loss: 0.0375 - val_loss: 0.0218
# Epoch 3/20
# 8/8 [==============================] - 0s 49ms/step - loss: 0.0356 - val_loss: 0.0212
# Epoch 4/20
# 8/8 [==============================] - 0s 51ms/step - loss: 0.0368 - val_loss: 0.0217
# Epoch 5/20
# 8/8 [==============================] - 0s 50ms/step - loss: 0.0378 - val_loss: 0.0212
# Epoch 6/20
# 8/8 [==============================] - 0s 51ms/step - loss: 0.0336 - val_loss: 0.0224
# Epoch 7/20
# 8/8 [==============================] - 0s 49ms/step - loss: 0.0324 - val_loss: 0.0227
# Epoch 8/20
# 8/8 [==============================] - 0s 53ms/step - loss: 0.0349 - val_loss: 0.0255
# Epoch 9/20
# 8/8 [==============================] - 0s 49ms/step - loss: 0.0349 - val_loss: 0.0227
# Epoch 10/20
# 8/8 [==============================] - 0s 52ms/step - loss: 0.0384 - val_loss: 0.0226
# Epoch 11/20
# 8/8 [==============================] - 0s 51ms/step - loss: 0.0336 - val_loss: 0.0214
# Epoch 12/20
# 8/8 [==============================] - 0s 50ms/step - loss: 0.0314 - val_loss: 0.0213
# Epoch 13/20
# 8/8 [==============================] - 0s 50ms/step - loss: 0.0351 - val_loss: 0.0219
# Epoch 14/20
# 8/8 [==============================] - 0s 50ms/step - loss: 0.0338 - val_loss: 0.0220
# Epoch 15/20
# 8/8 [==============================] - 0s 53ms/step - loss: 0.0305 - val_loss: 0.0236
# Epoch 16/20
# 8/8 [==============================] - 0s 51ms/step - loss: 0.0321 - val_loss: 0.0259
# Epoch 17/20
# 8/8 [==============================] - 0s 52ms/step - loss: 0.0329 - val_loss: 0.0233
# Epoch 18/20
# 8/8 [==============================] - 0s 52ms/step - loss: 0.0330 - val_loss: 0.0222
# Epoch 19/20
# 8/8 [==============================] - 0s 52ms/step - loss: 0.0320 - val_loss: 0.0227
# Epoch 20/20
# 8/8 [==============================] - 0s 52ms/step - loss: 0.0332 - val_loss: 0.0219

# %% [markdown]
# # split_fraction = 0.8, lags = 20

# %%
obj = TimeSeries(address="Data/Data_ICME_speed_transformed_18D_P03_01", split_fraction = 0.8, lags = 20)

# %%
obj.plot()
obj.fit_lstm(epochs=20)
obj.model_predict()
obj.compare_test_result()
# Out:
# Epoch 1/20
# 10/10 [==============================] - 2s 214ms/step - loss: 0.0646 - val_loss: 0.0169
# Epoch 2/20
# 10/10 [==============================] - 0s 24ms/step - loss: 0.0342 - val_loss: 0.0158
# Epoch 3/20
# 10/10 [==============================] - 0s 25ms/step - loss: 0.0349 - val_loss: 0.0159
# Epoch 4/20
# 10/10 [==============================] - 0s 24ms/step - loss: 0.0341 - val_loss: 0.0172
# Epoch 5/20
# 10/10 [==============================] - 0s 25ms/step - loss: 0.0313 - val_loss: 0.0178
# Epoch 6/20
# 10/10 [==============================] - 0s 23ms/step - loss: 0.0325 - val_loss: 0.0168
# Epoch 7/20
# 10/10 [==============================] - 0s 24ms/step - loss: 0.0308 - val_loss: 0.0159
# Epoch 8/20
# 10/10 [==============================] - 0s 25ms/step - loss: 0.0318 - val_loss: 0.0180
# Epoch 9/20
# 10/10 [==============================] - 0s 24ms/step - loss: 0.0295 - val_loss: 0.0163
# Epoch 10/20
# 10/10 [==============================] - 0s 25ms/step - loss: 0.0304 - val_loss: 0.0228
# Epoch 11/20
# 10/10 [==============================] - 0s 24ms/step - loss: 0.0302 - val_loss: 0.0174
# Epoch 12/20
# 10/10 [==============================] - 0s 27ms/step - loss: 0.0303 - val_loss: 0.0178
# Epoch 13/20
# 10/10 [==============================] - 0s 25ms/step - loss: 0.0318 - val_loss: 0.0178
# Epoch 14/20
# 10/10 [==============================] - 0s 22ms/step - loss: 0.0301 - val_loss: 0.0170
# Epoch 15/20
# 10/10 [==============================] - 0s 23ms/step - loss: 0.0310 - val_loss: 0.0161
# Epoch 16/20
# 10/10 [==============================] - 0s 26ms/step - loss: 0.0312 - val_loss: 0.0163
# Epoch 17/20
# 10/10 [==============================] - 0s 25ms/step - loss: 0.0303 - val_loss: 0.0183
# Epoch 18/20
# 10/10 [==============================] - 0s 24ms/step - loss: 0.0295 - val_loss: 0.0163
# Epoch 19/20
# 10/10 [==============================] - 0s 25ms/step - loss: 0.0296 - val_loss: 0.0175

# %% [markdown]
# # split_fraction = 0.8, lags = 10

# %%
obj = TimeSeries(address="Data/Data_ICME_speed_transformed_18D_P03_01", split_fraction = 0.8, lags = 10)

# %%
obj.plot()

# %%
obj.fit_lstm(epochs=20)
obj.model_predict()
obj.compare_test_result()
# Out:
# Epoch 1/20
# 10/10 [==============================] - 2s 153ms/step - loss: 0.0812 - val_loss: 0.0309
# Epoch 2/20
# 10/10 [==============================] - 0s 15ms/step - loss: 0.0463 - val_loss: 0.0163
# Epoch 3/20
# 10/10 [==============================] - 0s 16ms/step - loss: 0.0351 - val_loss: 0.0158
# Epoch 4/20
# 10/10 [==============================] - 0s 16ms/step - loss: 0.0341 - val_loss: 0.0157
# Epoch 5/20
# 10/10 [==============================] - 0s 16ms/step - loss: 0.0327 - val_loss: 0.0155
# Epoch 6/20
# 10/10 [==============================] - 0s 18ms/step - loss: 0.0328 - val_loss: 0.0159
# Epoch 7/20
# 10/10 [==============================] - 0s 17ms/step - loss: 0.0318 - val_loss: 0.0161
# Epoch 8/20
# 10/10 [==============================] - 0s 16ms/step - loss: 0.0309 - val_loss: 0.0162
# Epoch 9/20
# 10/10 [==============================] - 0s 16ms/step - loss: 0.0325 - val_loss: 0.0154
# Epoch 10/20
# 10/10 [==============================] - 0s 16ms/step - loss: 0.0306 - val_loss: 0.0161
# Epoch 11/20
# 10/10 [==============================] - 0s 16ms/step - loss: 0.0305 - val_loss: 0.0157
# Epoch 12/20
# 10/10 [==============================] - 0s 15ms/step - loss: 0.0293 - val_loss: 0.0175
# Epoch 13/20
# 10/10 [==============================] - 0s 15ms/step - loss: 0.0343 - val_loss: 0.0173
# Epoch 14/20
# 10/10 [==============================] - 0s 17ms/step - loss: 0.0305 - val_loss: 0.0164
# Epoch 15/20
# 10/10 [==============================] - 0s 16ms/step - loss: 0.0314 - val_loss: 0.0164
# Epoch 16/20
# 10/10 [==============================] - 0s 15ms/step - loss: 0.0303 - val_loss: 0.0175
# Epoch 17/20
# 10/10 [==============================] - 0s 16ms/step - loss: 0.0308 - val_loss: 0.0159
# Epoch 18/20
# 10/10 [==============================] - 0s 17ms/step - loss: 0.0284 - val_loss: 0.0171
# Epoch 19/20
# 10/10 [==============================] - 0s 16ms/step - loss: 0.0301 - val_loss: 0.0172
# Epoch 20/20
# 10/10 [==============================] - 0s 16ms/step - loss: 0.0307 - val_loss: 0.0161

# %% [markdown]
# # split_fraction = 0.5, lags = 5

# %%
obj = TimeSeries(address="Data/Data_ICME_speed_transformed_18D_P03_01", split_fraction = 0.5, lags = 5)

# %%
obj.plot()

# %%
obj.fit_lstm(epochs=20)
obj.model_predict()
obj.compare_test_result()
# Out:
# Epoch 1/20
# 7/7 [==============================] - 1s 207ms/step - loss: 0.0967 - val_loss: 0.0228
# Epoch 2/20
# 7/7 [==============================] - 0s 14ms/step - loss: 0.0768 - val_loss: 0.0152
# Epoch 3/20
# 7/7 [==============================] - 0s 14ms/step - loss: 0.0652 - val_loss: 0.0107
# Epoch 4/20
# 7/7 [==============================] - 0s 13ms/step - loss: 0.0552 - val_loss: 0.0093
# Epoch 5/20
# 7/7 [==============================] - 0s 13ms/step - loss: 0.0499 - val_loss: 0.0096
# Epoch 6/20
# 7/7 [==============================] - 0s 13ms/step - loss: 0.0470 - val_loss: 0.0110
# Epoch 7/20
# 7/7 [==============================] - 0s 12ms/step - loss: 0.0453 - val_loss: 0.0125
# Epoch 8/20
# 7/7 [==============================] - 0s 13ms/step - loss: 0.0392 - val_loss: 0.0132
# Epoch 9/20
# 7/7 [==============================] - 0s 13ms/step - loss: 0.0394 - val_loss: 0.0181
# Epoch 10/20
# 7/7 [==============================] - 0s 13ms/step - loss: 0.0414 - val_loss: 0.0170
# Epoch 11/20
# 7/7 [==============================] - 0s 13ms/step - loss: 0.0412 - val_loss: 0.0178
# Epoch 12/20
# 7/7 [==============================] - 0s 13ms/step - loss: 0.0414 - val_loss: 0.0148
# Epoch 13/20
# 7/7 [==============================] - 0s 13ms/step - loss: 0.0425 - val_loss: 0.0174
# Epoch 14/20
# 7/7 [==============================] - 0s 14ms/step - loss: 0.0400 - val_loss: 0.0182
# Epoch 15/20
# 7/7 [==============================] - 0s 13ms/step - loss: 0.0406 - val_loss: 0.0184
# Epoch 16/20
# 7/7 [==============================] - 0s 13ms/step - loss: 0.0365 - val_loss: 0.0195
# Epoch 17/20
# 7/7 [==============================] - 0s 13ms/step - loss: 0.0436 - val_loss: 0.0182
# Epoch 18/20
# 7/7 [==============================] - 0s 14ms/step - loss: 0.0431 - val_loss: 0.0181
# Epoch 19/20
# 7/7 [==============================] - 0s 13ms/step - loss: 0.0420 - val_loss: 0.0145
# Epoch 20/20
# 7/7 [==============================] - 0s 13ms/step - loss: 0.0440 - val_loss: 0.0153
