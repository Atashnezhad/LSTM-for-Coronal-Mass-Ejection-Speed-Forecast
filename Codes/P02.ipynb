# %%
import os, sys
import requests
from urllib.parse import urljoin, urlparse
from bs4 import BeautifulSoup as bs
import re
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
# %config InlineBackend.figure_format = 'retina'
from pandas.plotting import lag_plot

# %%
from sklearn.metrics import r2_score
from math import sqrt

# %%
import warnings
warnings.filterwarnings('ignore')
warnings.simplefilter(action='ignore', category=FutureWarning)

# %%
from sklearn.preprocessing import MinMaxScaler
from keras.models import Sequential
from keras.layers import Dense, LSTM, Dropout, GRU, Bidirectional
# from keras.optimizers import SGD
from tensorflow.keras.optimizers import SGD

import math
from sklearn.metrics import mean_squared_error

# %%
from sklearn.linear_model import LinearRegression
from sklearn.preprocessing import StandardScaler, PolynomialFeatures

# %%
# !pip install gif

# %%
from pandas.plotting import autocorrelation_plot
# import gif
import json

# %%
from statsmodels.tsa.ar_model import AutoReg
from sklearn.metrics import mean_squared_error

# %%
import tensorflow as tf
tf.__version__

import tensorflow as tf
from tensorflow import keras

from tqdm import tqdm

# %%
from sklearn import metrics
import statsmodels.api as sm

# %%
import sys
import os
from os.path import dirname

# %%
os.path.abspath('')
# Out:
# '/home/ec2-user/SageMaker/Codes'

# %%
parent = (dirname(os.path.abspath('')))
sys.path.insert(0, parent)

# %%
parent
# Out:
# '/home/ec2-user/SageMaker'

# %%
from utils import TimeSeries

# %% [markdown]
# # Read Datam

# %%
class LSTM_2(TimeSeries):
    # override
    def _setup_lstm_model(self, 
                   optimizer:str='rmsprop', 
                   loss:str='mean_squared_error',
                   print_summary:bool = False):
        

        
        self.regressor = Sequential()
        self.regressor.add(Bidirectional(LSTM(50, activation='relu'), 
                                         input_shape=(self.X_train.shape[1],1)))
        self.regressor.add(Dense(1))
        self.regressor.compile(optimizer='adam', loss='mean_squared_error')
        if print_summary:
            self.regressor.summary()

# %%
obj = LSTM_2(address=parent+"/Data/Data_ICME_speed_transformed_18D_P03_01")

# %% [markdown]
# # split_fraction = 0.69, lags = 60

# %%
obj.plot()
obj.fit_lstm(epochs=20)
obj.model_predict()
obj.compare_test_result()
# Out:
# Epoch 1/20
# 8/8 [==============================] - 1s 75ms/step - loss: 0.0736 - val_loss: 0.0324
# Epoch 2/20
# 8/8 [==============================] - 0s 33ms/step - loss: 0.0355 - val_loss: 0.0220
# Epoch 3/20
# 8/8 [==============================] - 0s 29ms/step - loss: 0.0298 - val_loss: 0.0252
# Epoch 4/20
# 8/8 [==============================] - 0s 30ms/step - loss: 0.0282 - val_loss: 0.0209
# Epoch 5/20
# 8/8 [==============================] - 0s 29ms/step - loss: 0.0275 - val_loss: 0.0207
# Epoch 6/20
# 8/8 [==============================] - 0s 29ms/step - loss: 0.0270 - val_loss: 0.0210
# Epoch 7/20
# 8/8 [==============================] - 0s 29ms/step - loss: 0.0268 - val_loss: 0.0216
# Epoch 8/20
# 8/8 [==============================] - 0s 29ms/step - loss: 0.0268 - val_loss: 0.0215
# Epoch 9/20
# 8/8 [==============================] - 0s 29ms/step - loss: 0.0266 - val_loss: 0.0210
# Epoch 10/20
# 8/8 [==============================] - 0s 28ms/step - loss: 0.0264 - val_loss: 0.0209
# Epoch 11/20
# 8/8 [==============================] - 0s 29ms/step - loss: 0.0265 - val_loss: 0.0217
# Epoch 12/20
# 8/8 [==============================] - 0s 29ms/step - loss: 0.0264 - val_loss: 0.0207
# Epoch 13/20
# 8/8 [==============================] - 0s 27ms/step - loss: 0.0262 - val_loss: 0.0208
# Epoch 14/20
# 8/8 [==============================] - 0s 31ms/step - loss: 0.0262 - val_loss: 0.0209
# Epoch 15/20
# 8/8 [==============================] - 0s 30ms/step - loss: 0.0261 - val_loss: 0.0209
# Epoch 16/20
# 8/8 [==============================] - 0s 29ms/step - loss: 0.0260 - val_loss: 0.0208
# Epoch 17/20
# 8/8 [==============================] - 0s 29ms/step - loss: 0.0260 - val_loss: 0.0209
# Epoch 18/20
# 8/8 [==============================] - 0s 29ms/step - loss: 0.0259 - val_loss: 0.0208
# Epoch 19/20
# 8/8 [==============================] - 0s 30ms/step - loss: 0.0259 - val_loss: 0.0208
# Epoch 20/20
# 8/8 [==============================] - 0s 29ms/step - loss: 0.0259 - val_loss: 0.0210

# %% [markdown]
# # split_fraction = 0.8, lags = 20

# %%
obj = TimeSeries(address=parent+"/Data/Data_ICME_speed_transformed_18D_P03_01", split_fraction = 0.8, lags = 20)

# %%
obj.plot()
obj.fit_lstm(epochs=20)
obj.model_predict()
obj.compare_test_result()
# Out:
# Epoch 1/20
# 10/10 [==============================] - 2s 164ms/step - loss: 0.0797 - val_loss: 0.0261
# Epoch 2/20
# 10/10 [==============================] - 0s 24ms/step - loss: 0.0439 - val_loss: 0.0158
# Epoch 3/20
# 10/10 [==============================] - 0s 25ms/step - loss: 0.0355 - val_loss: 0.0161
# Epoch 4/20
# 10/10 [==============================] - 0s 25ms/step - loss: 0.0337 - val_loss: 0.0167
# Epoch 5/20
# 10/10 [==============================] - 0s 25ms/step - loss: 0.0339 - val_loss: 0.0170
# Epoch 6/20
# 10/10 [==============================] - 0s 24ms/step - loss: 0.0344 - val_loss: 0.0158
# Epoch 7/20
# 10/10 [==============================] - 0s 26ms/step - loss: 0.0299 - val_loss: 0.0163
# Epoch 8/20
# 10/10 [==============================] - 0s 28ms/step - loss: 0.0318 - val_loss: 0.0162
# Epoch 9/20
# 10/10 [==============================] - 0s 24ms/step - loss: 0.0351 - val_loss: 0.0174
# Epoch 10/20
# 10/10 [==============================] - 0s 23ms/step - loss: 0.0332 - val_loss: 0.0163
# Epoch 11/20
# 10/10 [==============================] - 0s 25ms/step - loss: 0.0330 - val_loss: 0.0172
# Epoch 12/20
# 10/10 [==============================] - 0s 25ms/step - loss: 0.0318 - val_loss: 0.0162
# Epoch 13/20
# 10/10 [==============================] - 0s 24ms/step - loss: 0.0321 - val_loss: 0.0168
# Epoch 14/20
# 10/10 [==============================] - 0s 25ms/step - loss: 0.0318 - val_loss: 0.0177
# Epoch 15/20
# 10/10 [==============================] - 0s 25ms/step - loss: 0.0298 - val_loss: 0.0164
# Epoch 16/20
# 10/10 [==============================] - 0s 25ms/step - loss: 0.0322 - val_loss: 0.0179
# Epoch 17/20
# 10/10 [==============================] - 0s 24ms/step - loss: 0.0310 - val_loss: 0.0160
# Epoch 18/20
# 10/10 [==============================] - 0s 25ms/step - loss: 0.0303 - val_loss: 0.0168
# Epoch 19/20
# 10/10 [==============================] - 0s 25ms/step - loss: 0.0298 - val_loss: 0.0176
# Epoch 20/20
# 10/10 [==============================] - 0s 27ms/step - loss: 0.0315 - val_loss: 0.0171

# %% [markdown]
# # split_fraction = 0.8, lags = 10

# %%
obj = TimeSeries(address=parent+"/Data/Data_ICME_speed_transformed_18D_P03_01", split_fraction = 0.8, lags = 10)

# %%
obj.plot()

# %%
obj.fit_lstm(epochs=20)
obj.model_predict()
obj.compare_test_result()
# Out:
# Epoch 1/20
# 10/10 [==============================] - 2s 175ms/step - loss: 0.0701 - val_loss: 0.0206
# Epoch 2/20
# 10/10 [==============================] - 0s 16ms/step - loss: 0.0413 - val_loss: 0.0154
# Epoch 3/20
# 10/10 [==============================] - 0s 16ms/step - loss: 0.0359 - val_loss: 0.0168
# Epoch 4/20
# 10/10 [==============================] - 0s 17ms/step - loss: 0.0342 - val_loss: 0.0153
# Epoch 5/20
# 10/10 [==============================] - 0s 16ms/step - loss: 0.0345 - val_loss: 0.0160
# Epoch 6/20
# 10/10 [==============================] - 0s 17ms/step - loss: 0.0314 - val_loss: 0.0153
# Epoch 7/20
# 10/10 [==============================] - 0s 16ms/step - loss: 0.0347 - val_loss: 0.0157
# Epoch 8/20
# 10/10 [==============================] - 0s 16ms/step - loss: 0.0329 - val_loss: 0.0160
# Epoch 9/20
# 10/10 [==============================] - 0s 18ms/step - loss: 0.0317 - val_loss: 0.0165
# Epoch 10/20
# 10/10 [==============================] - 0s 17ms/step - loss: 0.0327 - val_loss: 0.0156
# Epoch 11/20
# 10/10 [==============================] - 0s 17ms/step - loss: 0.0311 - val_loss: 0.0162
# Epoch 12/20
# 10/10 [==============================] - 0s 17ms/step - loss: 0.0319 - val_loss: 0.0159
# Epoch 13/20
# 10/10 [==============================] - 0s 16ms/step - loss: 0.0323 - val_loss: 0.0165
# Epoch 14/20
# 10/10 [==============================] - 0s 16ms/step - loss: 0.0311 - val_loss: 0.0160
# Epoch 15/20
# 10/10 [==============================] - 0s 16ms/step - loss: 0.0305 - val_loss: 0.0163
# Epoch 16/20
# 10/10 [==============================] - 0s 17ms/step - loss: 0.0292 - val_loss: 0.0161
# Epoch 17/20
# 10/10 [==============================] - 0s 18ms/step - loss: 0.0318 - val_loss: 0.0156
# Epoch 18/20
# 10/10 [==============================] - 0s 16ms/step - loss: 0.0298 - val_loss: 0.0166
# Epoch 19/20
# 10/10 [==============================] - 0s 16ms/step - loss: 0.0306 - val_loss: 0.0157
# Epoch 20/20
# 10/10 [==============================] - 0s 17ms/step - loss: 0.0289 - val_loss: 0.0167

# %% [markdown]
# # split_fraction = 0.5, lags = 5

# %%
obj = TimeSeries(address=parent+"/Data/Data_ICME_speed_transformed_18D_P03_01", split_fraction = 0.5, lags = 5)

# %%
obj.plot()

# %%
obj.fit_lstm(epochs=100)
obj.model_predict()
obj.compare_test_result()
# Out:
# Epoch 1/100
# 7/7 [==============================] - 2s 215ms/step - loss: 0.0947 - val_loss: 0.0218
# Epoch 2/100
# 7/7 [==============================] - 0s 14ms/step - loss: 0.0749 - val_loss: 0.0139
# Epoch 3/100
# 7/7 [==============================] - 0s 14ms/step - loss: 0.0582 - val_loss: 0.0097
# Epoch 4/100
# 7/7 [==============================] - 0s 13ms/step - loss: 0.0473 - val_loss: 0.0093
# Epoch 5/100
# 7/7 [==============================] - 0s 14ms/step - loss: 0.0464 - val_loss: 0.0102
# Epoch 6/100
# 7/7 [==============================] - 0s 14ms/step - loss: 0.0411 - val_loss: 0.0134
# Epoch 7/100
# 7/7 [==============================] - 0s 13ms/step - loss: 0.0441 - val_loss: 0.0127
# Epoch 8/100
# 7/7 [==============================] - 0s 13ms/step - loss: 0.0426 - val_loss: 0.0132
# Epoch 9/100
# 7/7 [==============================] - 0s 14ms/step - loss: 0.0428 - val_loss: 0.0132
# Epoch 10/100
# 7/7 [==============================] - 0s 14ms/step - loss: 0.0433 - val_loss: 0.0144
# Epoch 11/100
# 7/7 [==============================] - 0s 13ms/step - loss: 0.0415 - val_loss: 0.0132
# Epoch 12/100
# 7/7 [==============================] - 0s 13ms/step - loss: 0.0389 - val_loss: 0.0147
# Epoch 13/100
# 7/7 [==============================] - 0s 16ms/step - loss: 0.0389 - val_loss: 0.0156
# Epoch 14/100
# 7/7 [==============================] - 0s 16ms/step - loss: 0.0433 - val_loss: 0.0134
# Epoch 15/100
# 7/7 [==============================] - 0s 13ms/step - loss: 0.0420 - val_loss: 0.0136
# Epoch 16/100
# 7/7 [==============================] - 0s 14ms/step - loss: 0.0401 - val_loss: 0.0158
# Epoch 17/100
# 7/7 [==============================] - 0s 15ms/step - loss: 0.0406 - val_loss: 0.0173
# Epoch 18/100
# 7/7 [==============================] - 0s 13ms/step - loss: 0.0395 - val_loss: 0.0156
# Epoch 19/100
# 7/7 [==============================] - 0s 14ms/step - loss: 0.0417 - val_loss: 0.0157
# Epoch 20/100
# 7/7 [==============================] - 0s 14ms/step - loss: 0.0415 - val_loss: 0.0168
# Epoch 21/100
# 7/7 [==============================] - 0s 13ms/step - loss: 0.0392 - val_loss: 0.0183
# Epoch 22/100
# 7/7 [==============================] - 0s 14ms/step - loss: 0.0402 - val_loss: 0.0170
