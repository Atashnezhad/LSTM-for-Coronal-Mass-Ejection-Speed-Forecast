# %%
import os, sys
import requests
from urllib.parse import urljoin, urlparse
from bs4 import BeautifulSoup as bs
import re
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
# %config InlineBackend.figure_format = 'retina'
from pandas.plotting import lag_plot

# %%
from sklearn.metrics import r2_score
from math import sqrt

# %%
import warnings
warnings.filterwarnings('ignore')
warnings.simplefilter(action='ignore', category=FutureWarning)

# %%
from sklearn.preprocessing import MinMaxScaler
from keras.models import Sequential
from keras.layers import Dense, LSTM, Dropout, GRU, Bidirectional
# from keras.optimizers import SGD
from tensorflow.keras.optimizers import SGD

import math
from sklearn.metrics import mean_squared_error

# %%
from sklearn.linear_model import LinearRegression
from sklearn.preprocessing import StandardScaler, PolynomialFeatures

# %%
# !pip install gif

# %%
from pandas.plotting import autocorrelation_plot
import gif
import json

# %%
from statsmodels.tsa.ar_model import AutoReg
from sklearn.metrics import mean_squared_error

# %%
import tensorflow as tf
tf.__version__

import tensorflow as tf
from tensorflow import keras

import gif
from tqdm import tqdm

# %%
from sklearn import metrics
import statsmodels.api as sm

# %%
from utils import TimeSeries

# %% [markdown]
# # Read Datam

# %%
obj = TimeSeries(address="Data/Data_ICME_speed_transformed_18D_P03_01")

# %% [markdown]
# # split_fraction = 0.69, lags = 60

# %%
obj.plot()
obj.fit_lstm(epochs=20)
obj.model_predict()
obj.compare_test_result()
# Out:
# Epoch 1/20
# 8/8 [==============================] - 2s 226ms/step - loss: 0.0809 - val_loss: 0.0327
# Epoch 2/20
# 8/8 [==============================] - 0s 48ms/step - loss: 0.0461 - val_loss: 0.0213
# Epoch 3/20
# 8/8 [==============================] - 0s 51ms/step - loss: 0.0393 - val_loss: 0.0212
# Epoch 4/20
# 8/8 [==============================] - 0s 49ms/step - loss: 0.0394 - val_loss: 0.0214
# Epoch 5/20
# 8/8 [==============================] - 0s 49ms/step - loss: 0.0359 - val_loss: 0.0212
# Epoch 6/20
# 8/8 [==============================] - 0s 53ms/step - loss: 0.0365 - val_loss: 0.0219
# Epoch 7/20
# 8/8 [==============================] - 0s 50ms/step - loss: 0.0320 - val_loss: 0.0226
# Epoch 8/20
# 8/8 [==============================] - 0s 48ms/step - loss: 0.0332 - val_loss: 0.0239
# Epoch 9/20
# 8/8 [==============================] - 0s 50ms/step - loss: 0.0331 - val_loss: 0.0214
# Epoch 10/20
# 8/8 [==============================] - 0s 50ms/step - loss: 0.0336 - val_loss: 0.0215
# Epoch 11/20
# 8/8 [==============================] - 0s 49ms/step - loss: 0.0362 - val_loss: 0.0217
# Epoch 12/20
# 8/8 [==============================] - 0s 50ms/step - loss: 0.0332 - val_loss: 0.0231
# Epoch 13/20
# 8/8 [==============================] - 0s 52ms/step - loss: 0.0325 - val_loss: 0.0213
# Epoch 14/20
# 8/8 [==============================] - 0s 52ms/step - loss: 0.0324 - val_loss: 0.0213
# Epoch 15/20
# 8/8 [==============================] - 0s 50ms/step - loss: 0.0327 - val_loss: 0.0244
# Epoch 16/20
# 8/8 [==============================] - 0s 51ms/step - loss: 0.0310 - val_loss: 0.0213
# Epoch 17/20
# 8/8 [==============================] - 0s 49ms/step - loss: 0.0331 - val_loss: 0.0219
# Epoch 18/20
# 8/8 [==============================] - 0s 54ms/step - loss: 0.0317 - val_loss: 0.0226
# Epoch 19/20
# 8/8 [==============================] - 0s 54ms/step - loss: 0.0322 - val_loss: 0.0221
# Epoch 20/20
# 8/8 [==============================] - 0s 53ms/step - loss: 0.0312 - val_loss: 0.0213

# %% [markdown]
# # split_fraction = 0.8, lags = 20

# %%
obj = TimeSeries(address="Data/Data_ICME_speed_transformed_18D_P03_01", split_fraction = 0.8, lags = 20)

# %%
obj.plot()
obj.fit_lstm(epochs=20)
obj.model_predict()
obj.compare_test_result()
# Out:
# Epoch 1/20
# 10/10 [==============================] - 2s 156ms/step - loss: 0.1041 - val_loss: 0.0263
# Epoch 2/20
# 10/10 [==============================] - 0s 21ms/step - loss: 0.0427 - val_loss: 0.0154
# Epoch 3/20
# 10/10 [==============================] - 0s 21ms/step - loss: 0.0369 - val_loss: 0.0155
# Epoch 4/20
# 10/10 [==============================] - 0s 22ms/step - loss: 0.0363 - val_loss: 0.0181
# Epoch 5/20
# 10/10 [==============================] - 0s 22ms/step - loss: 0.0365 - val_loss: 0.0164
# Epoch 6/20
# 10/10 [==============================] - 0s 22ms/step - loss: 0.0357 - val_loss: 0.0153
# Epoch 7/20
# 10/10 [==============================] - 0s 22ms/step - loss: 0.0366 - val_loss: 0.0158
# Epoch 8/20
# 10/10 [==============================] - 0s 22ms/step - loss: 0.0366 - val_loss: 0.0157
# Epoch 9/20
# 10/10 [==============================] - 0s 23ms/step - loss: 0.0336 - val_loss: 0.0176
# Epoch 10/20
# 10/10 [==============================] - 0s 22ms/step - loss: 0.0321 - val_loss: 0.0177
# Epoch 11/20
# 10/10 [==============================] - 0s 25ms/step - loss: 0.0328 - val_loss: 0.0172
# Epoch 12/20
# 10/10 [==============================] - 0s 22ms/step - loss: 0.0328 - val_loss: 0.0161
# Epoch 13/20
# 10/10 [==============================] - 0s 22ms/step - loss: 0.0326 - val_loss: 0.0157
# Epoch 14/20
# 10/10 [==============================] - 0s 22ms/step - loss: 0.0311 - val_loss: 0.0167
# Epoch 15/20
# 10/10 [==============================] - 0s 21ms/step - loss: 0.0341 - val_loss: 0.0166
# Epoch 16/20
# 10/10 [==============================] - 0s 21ms/step - loss: 0.0307 - val_loss: 0.0209
# Epoch 17/20
# 10/10 [==============================] - 0s 23ms/step - loss: 0.0320 - val_loss: 0.0181
# Epoch 18/20
# 10/10 [==============================] - 0s 21ms/step - loss: 0.0316 - val_loss: 0.0183
# Epoch 19/20
# 10/10 [==============================] - 0s 21ms/step - loss: 0.0303 - val_loss: 0.0180
# Epoch 20/20
# 10/10 [==============================] - 0s 32ms/step - loss: 0.0293 - val_loss: 0.0164

# %% [markdown]
# # split_fraction = 0.8, lags = 10

# %%
obj = TimeSeries(address="Data/Data_ICME_speed_transformed_18D_P03_01", split_fraction = 0.8, lags = 10)

# %%
obj.plot()

# %%
obj.fit_lstm(epochs=20)
obj.model_predict()
obj.compare_test_result()
# Out:
# Epoch 1/20
# 10/10 [==============================] - 2s 151ms/step - loss: 0.0799 - val_loss: 0.0317
# Epoch 2/20
# 10/10 [==============================] - 0s 14ms/step - loss: 0.0496 - val_loss: 0.0172
# Epoch 3/20
# 10/10 [==============================] - 0s 15ms/step - loss: 0.0343 - val_loss: 0.0156
# Epoch 4/20
# 10/10 [==============================] - 0s 15ms/step - loss: 0.0331 - val_loss: 0.0154
# Epoch 5/20
# 10/10 [==============================] - 0s 14ms/step - loss: 0.0318 - val_loss: 0.0158
# Epoch 6/20
# 10/10 [==============================] - 0s 16ms/step - loss: 0.0343 - val_loss: 0.0159
# Epoch 7/20
# 10/10 [==============================] - 0s 14ms/step - loss: 0.0296 - val_loss: 0.0166
# Epoch 8/20
# 10/10 [==============================] - 0s 14ms/step - loss: 0.0320 - val_loss: 0.0179
# Epoch 9/20
# 10/10 [==============================] - 0s 14ms/step - loss: 0.0300 - val_loss: 0.0168
# Epoch 10/20
# 10/10 [==============================] - 0s 15ms/step - loss: 0.0320 - val_loss: 0.0160
# Epoch 11/20
# 10/10 [==============================] - 0s 15ms/step - loss: 0.0326 - val_loss: 0.0168
# Epoch 12/20
# 10/10 [==============================] - 0s 15ms/step - loss: 0.0297 - val_loss: 0.0172
# Epoch 13/20
# 10/10 [==============================] - 0s 15ms/step - loss: 0.0297 - val_loss: 0.0171
# Epoch 14/20
# 10/10 [==============================] - 0s 15ms/step - loss: 0.0307 - val_loss: 0.0163
# Epoch 15/20
# 10/10 [==============================] - 0s 15ms/step - loss: 0.0297 - val_loss: 0.0168
# Epoch 16/20
# 10/10 [==============================] - 0s 15ms/step - loss: 0.0311 - val_loss: 0.0168
# Epoch 17/20
# 10/10 [==============================] - 0s 14ms/step - loss: 0.0311 - val_loss: 0.0164
